# %%
#Matplotlib 基础
#Matplotlib是一个类似Matlab的工具包

# %%
#导入 matplotlib 和 numpy

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
#plot 二维图

# %%
#当只给定 y 值，默认以下标为 x 轴：

# %%
# %matplotlib inline
x = linspace(0, 2 * pi, 50)
plot(sin(x))

# %%
#给定 x 和 y 值：

# %%
plot(x, sin(x))

# %%
#多条数据线：

# %%
plot(x, sin(x),
    x, sin(2 * x))
# Out:
# [<matplotlib.lines.Line2D at 0x2a2c6379cc0>,
#  <matplotlib.lines.Line2D at 0x2a2c6379e80>]

# %%
#使用字符串，给定线条参数：

# %%
plot(x, sin(x), 'r-^')

# %%
#scatter 散点图

# %%
plot(x, sin(x), 'bo')

# %%
#scatter 可以达到同样的效果

# %%
scatter(x, sin(x))

# %%
#只是因为默认的坐标轴不一样，所以图像看上去有一点区别，但无实质区别

# %%
#scatter函数与Matlab的用法相同，还可以指定它的大小，颜色等参数：

# %%
x = rand(200)
y = rand(200)
size = rand(200) * 30
color = rand(200)
scatter(x, y, size, color)
# 显示颜色条
colorbar()

# %%
#坐标轴，标题，网格

# %%
#设置坐标轴的标签和标题
plot(x, sin(x))
xlabel('radians')
# 可以设置字体大小
ylabel('amplitude', fontsize='large')
title('Sin(x)')

# %%
plot(x, sin(x))
xlabel('radians')
# 可以设置字体大小
ylabel('amplitude', fontsize='normal')#观察字体区别
title('Sin(x)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\font_manager.py in set_size(self, size)
#     900         try:
# --> 901             size = float(size)
#     902         except ValueError:
#
# ValueError: could not convert string to float: 'normal'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-e2b6748ebe24> in <module>()
#       2 xlabel('radians')
#       3 # 可以设置字体大小
# ----> 4 ylabel('amplitude', fontsize='normal')#观察字体区别
#       5 title('Sin(x)')
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\pyplot.py in ylabel(s, *args, **kwargs)
#    1548             work.
#    1549     """
# -> 1550     return gca().set_ylabel(s, *args, **kwargs)
#    1551
#    1552
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_ylabel(self, ylabel, fontdict, labelpad, **kwargs)
#     240         if labelpad is not None:
#     241             self.yaxis.labelpad = labelpad
# --> 242         return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#     243
#     244     def _get_legend_handles(self, legend_handler_map=None):
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1476         if fontdict is not None:
#    1477             self.label.update(fontdict)
# -> 1478         self.label.update(kwargs)
#    1479         self.stale = True
#    1480         return self.label
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     240         """
#     241         bbox = kwargs.pop('bbox', None)
# --> 242         super(Text, self).update(kwargs)
#     243         if bbox:
#     244             self.set_bbox(bbox)  # depends on font properties
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     855                 if func is None or not six.callable(func):
#     856                     raise AttributeError('Unknown property %s' % k)
# --> 857                 func(v)
#     858             changed = True
#     859         self.eventson = store
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\text.py in set_fontsize(self, fontsize)
#    1108     def set_fontsize(self, fontsize):
#    1109         'alias for set_size'
# -> 1110         return self.set_size(fontsize)
#    1111
#    1112     def set_weight(self, weight):
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\text.py in set_size(self, fontsize)
#    1103                   'medium' | 'large' | 'x-large' | 'xx-large' ]
#    1104         """
# -> 1105         self._fontproperties.set_size(fontsize)
#    1106         self.stale = True
#    1107
#
# C:\Users\许某某\Anaconda3\lib\site-packages\matplotlib\font_manager.py in set_size(self, size)
#     904                 raise ValueError(
#     905                     "Size is invalid. Valid font size are " + ", ".join(
# --> 906                         str(i) for i in font_scalings.keys()))
#     907         self._size = size
#     908
#
# ValueError: Size is invalid. Valid font size are x-large, None, smaller, xx-small, large, medium, small, larger, x-small, xx-large

# %%
#坐标轴，标题，网格
#可以设置坐标轴的标签和标题：

# %%
plot(x, sin(x))
xlabel('radians')
# 可以设置字体大小
ylabel('amplitude', fontsize='large')
title('Sin(x)')

# %%
#用 'grid()' 来显示网格：

# %%
plot(x, sin(x))
xlabel('radians')
ylabel('amplitude', fontsize='large')
title('Sin(x)')
grid()
